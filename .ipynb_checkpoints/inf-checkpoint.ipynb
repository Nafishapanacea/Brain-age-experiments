# %%
import os
import subprocess
import torch
from torch.utils.data import DataLoader
from monai import transforms
from monai.data import Dataset
from monai.networks.nets.densenet import DenseNet201

# %%
template_path = '/home/jupyter-nafisha/Brain_age/templates/MNI152_T1_1mm_Brain.nii.gz'
model_path = "/home/jupyter-nafisha/Brain_age/synthstrip.pt"

# %%
# path = '/home/jupyter-nafisha/Brain_age/Abide_IXI_data/abide_10.nii.gz'

# %%
ants_bin = "/home/jupyter-nafisha/Brain_age/ants_2_6_3/ants-2.6.3/bin"
env = os.environ.copy()
env["PATH"] = ants_bin + ":" + env["PATH"]

def preprocessing(input_path, model_path, template_path):
    strip_out = os.path.join('/home/jupyter-nafisha/Brain_age/Temp_output', 'stripped.nii.gz')
    cmd = [
        "/home/jupyter-nafisha/.local/bin/nipreps-synthstrip",
        "-i", input_path,
        "-o", strip_out,
        "--model", model_path
    ]

    result = subprocess.run(cmd, capture_output=True, text=True)
    # result = subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    output_path = '/home/jupyter-nafisha/Brain_age/Temp_output/regis_' 
    reg_cmd = [
        f"{ants_bin}/antsRegistrationSyNQuick.sh",
        "-d", "3",
        "-f", template_path,
        "-m", strip_out,
        "-o", output_path
    ]
    subprocess.run(reg_cmd, env=env, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    
    return output_path + "Warped.nii.gz"

# %%
def get_inputs(inputs_path: str) -> list:
    
    def get_inputs_from_dir(inputs_path: str) -> list:
        is_nii = lambda f: f.endswith('.nii') or f.endswith('.nii.gz')
        files = os.listdir(inputs_path)
        input_paths = [ os.path.join(inputs_path, f) for f in files if is_nii(f) ]
        return input_paths

    def get_inputs_from_csv(inputs_path: str) -> list:
        with open(inputs_path, 'r') as f:
            return [ p.strip() for p in f.readlines() ]
        
    return get_inputs_from_dir(inputs_path) if os.path.isdir(inputs_path) \
        else get_inputs_from_csv(inputs_path)

transforms_fn = transforms.Compose([
    transforms.CopyItemsD(keys={'scan_path'}, names=['image']),
    transforms.LoadImageD(keys='image'),
    transforms.EnsureChannelFirstD(keys='image', channel_dim='no_channel'),
    transforms.SpacingD(keys='image', pixdim=1.4),
    transforms.ResizeWithPadOrCropD(keys='image', spatial_size=(130, 130, 130), mode='minimum'),
    transforms.ScaleIntensityD(keys='image', minv=0, maxv=1),
    transforms.Lambda(lambda d: d['image']),
])

# %%
# model = DenseNet201(3, 1, 1, dropout_prob=0)
# model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# model = model.to(DEVICE).eval()

# %%
# input_folder = '/home/jupyter-nafisha/Brain_age/stripped'
# input_folder = '/home/jupyter-nafisha/Brain_age/Data'

# input_paths = get_inputs(input_folder)
# if len(input_paths) < 1: 
#     print('No images to process. Exiting.')
#     exit()

# preprocessed_paths = []
# for path in input_paths:
#     out_path= preprocessing(path, model_path, template_path)
#     preprocessed_paths.append(out_path)

# model_path = '/home/jupyter-nafisha/Brain_age/synthba-g.pth'
# DEVICE = 'cpu'
# batch_size = 1

# %%
# model

# %%
# # prepare the dataset
# data = [ { 'scan_path': p } for p in preprocessed_paths ]
# dataset = Dataset(data=data, transform=transforms_fn)    
# loader = DataLoader(dataset=dataset, batch_size=1)

# %%
# brain_age_list = []
# for i, images in enumerate(loader):
#     print(f'processing batch n.{i}')
#     with torch.no_grad():
#         brain_ages = model(images.to(DEVICE))
#         brain_age_list += list(brain_ages.view(-1).cpu().numpy() * 100)
#     break

# %%
densenet_path = '/home/jupyter-nafisha/Brain_age/synthba-g.pth'
DEVICE = 'cpu'
batch_size = 1

model = DenseNet201(3, 1, 1, dropout_prob=0)
model.load_state_dict(torch.load(densenet_path, map_location=DEVICE))
model = model.to(DEVICE).eval()

# %%
# IXI

# input_folder = '/home/common/IXI-T1'

# input_paths = get_inputs(input_folder)
# if len(input_paths) < 1: 
#     print('No images to process. Exiting.')
#     exit()

# %%
# Abide

import pandas as pd
df= pd.read_csv('ABIDE_I_relative_paths_with_age_sex.csv')
input_paths = list(df['relative_path'])[0:50]

# %%
# files

# %%
# input_folder = '/home/jupyter-nafisha/Brain_age/stripped'

# count=0

brain_age_list = []
full_list = []

for path in input_paths:
    out_path= preprocessing(path, model_path, template_path)

    dataset = Dataset(data= [{ 'scan_path': out_path }], transform=transforms_fn)  
    loader = DataLoader(dataset=dataset, batch_size=1)

    for i, images in enumerate(loader):
        print(f'processing batch n.{i}')
        with torch.no_grad():
            brain_ages = model(images.to(DEVICE))
            brain_age_list += list(brain_ages.view(-1).cpu().numpy() * 100)
            # full_list.append([path, brain_ages.view(-1).cpu().numpy() * 100])
        print(path, brain_ages.view(-1).cpu().numpy() * 100)
    
    # count+=1
    # if count==50:
    #     break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       6 full_list = []
#       8 for path in input_paths:
# ----> 9     out_path= preprocessing(path, model_path, template_path)
#      11     dataset = Dataset(data= [{ 'scan_path': out_path }], transform=transforms_fn)
#      12     loader = DataLoader(dataset=dataset, batch_size=1)
#
# Cell In[4], line 14, in preprocessing(input_path, model_path, template_path)
#       6 strip_out = os.path.join('/home/jupyter-nafisha/Brain_age/Temp_output', 'stripped.nii.gz')
#       7 cmd = [
#       8     "/home/jupyter-nafisha/.local/bin/nipreps-synthstrip",
#       9     "-i", input_path,
#      10     "-o", strip_out,
#      11     "--model", model_path
#      12 ]
# ---> 14 result = subprocess.run(cmd, capture_output=True, text=True)
#      15 # result = subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
#      17 output_path = '/home/jupyter-nafisha/Brain_age/Temp_output/regis_'
#
# File /opt/tljh/user/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /opt/tljh/user/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /opt/tljh/user/lib/python3.12/subprocess.py:2115, in Popen._communicate(self, input, endtime, orig_timeout)
#    2108     self._check_timeout(endtime, orig_timeout,
#    2109                         stdout, stderr,
#    2110                         skip_check_and_raise=True)
#    2111     raise RuntimeError(  # Impossible :)
#    2112         '_check_timeout(..., skip_check_and_raise=True) '
#    2113         'failed to raise TimeoutExpired.')
# -> 2115 ready = selector.select(timeout)
#    2116 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2118 # XXX Rewrite these to use non-blocking I/O on the file
#    2119 # objects; they are no longer using C stdio!
#
# File /opt/tljh/user/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
# brain_age_list
# full_list

# %%
csv_path = '/home/jupyter-nafisha/Brain_age/Temp_output/predictions_abide.csv'
with open(csv_path, 'w') as csv:
    csv.write("input_id,brainage\n")
    for scan_path, brain_age in zip(input_paths, brain_age_list):
        csv.write(f"{scan_path},{brain_age}\n")

# %%
brain_age_list
# Out:
# [np.float32(20.9945)]

# %% [markdown]
# # MAE calculation

# %%
import pandas as pd

csv_path = '/home/jupyter-nafisha/Brain_age/Temp_output/prediction_IXI.csv'
pred= pd.read_csv(csv_path)

# %%
# pred['input_id'] = pred['input_id'].str.replace('/home/common/IXI-T1/', '', regex=False)
# pred

# %%
import numpy as np

mae = np.mean(np.abs(pred['actual_age'] - pred['predicted_age']))
print("MAE =", mae)
# Out:
# MAE = 11.860384801605687

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
plt.scatter(pred['actual_age'], pred['predicted_age'], alpha=0.6)

# Add diagonal y=x line
x = np.linspace(pred['actual_age'].min(), pred['actual_age'].max(), 100)
plt.plot(x, x, linestyle='--')

plt.xlabel('Actual Age')
plt.ylabel('Predicted Brain Age')
plt.title('Actual Age vs Predicted Brain Age')
plt.grid(True)
plt.show()

# %%
# making Zip of data for freesurfer

# %%
pwd
# Out:
# '/home/jupyter-nafisha/Brain_age'

# %%
import shutil
dest_dir = '/home/jupyter-nafisha/Brain_age/IXI_data'
for itr, row in final_df.iterrows():
    file_path= os.path.join('/home/common/IXI-T1', row['input_id'])
    shutil.copy(file_path, dest_dir)

# %%
import shutil

dest_dir = '/home/jupyter-nafisha/Brain_age/IXI_data'
zip_path = '/home/jupyter-nafisha/Brain_age/IXI_data'

shutil.make_archive(zip_path, 'zip', dest_dir)
# Out:
# '/home/jupyter-nafisha/Brain_age/IXI_data.zip'

# %%
import pandas as pd
df= pd.read_csv('ABIDE_I_relative_paths_with_age_sex.csv')
df
# Out:
#            subject                                      relative_path  \
# 0        CMU_50665       CMU_50665/CMU_50665/anat/NIfTI/mprage.nii.gz
# 1     Leuven_50707  Leuven_50707/Leuven_50707/anat/NIfTI/mprage.ni...
# 2       OHSU_50160     OHSU_50160/OHSU_50160/anat/NIfTI/mprage.nii.gz
# 3       Yale_50577     Yale_50577/Yale_50577/anat/NIfTI/mprage.nii.gz
# 4       SDSU_50198     SDSU_50198/SDSU_50198/anat/NIfTI/mprage.nii.gz
# ..             ...                                                ...
# 566     OHSU_50161     OHSU_50161/OHSU_50161/anat/NIfTI/mprage.nii.gz
# 567  Caltech_51476  Caltech_51476/Caltech_51476/anat/NIfTI/mprage....
# 568   MaxMun_51363  MaxMun_51363/MaxMun_51363/anat/NIfTI/mprage.ni...
# 569   MaxMun_51341  MaxMun_51341/MaxMun_51341/anat/NIfTI/mprage.ni...
# 570   Leuven_50742  Leuven_50742/Leuven_50742/anat/NIfTI/mprage.ni...
#
#      age_at_scan  sex
# 0          33.00    1
# 1          22.00    1
# 2          11.45    1
# 3          15.25    1
# 4          15.28    1
# ..           ...  ...
# 566         9.15    1
# 567        39.30    1
# 568        32.00    1
# 569        29.00    1
# 570        16.90    1
#
# [571 rows x 4 columns]

# %%
df= pd.read_csv('ABIDE_I_relative_paths_with_age_sex.csv')
dest_dir = '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I'
df['relative_path'] = df['relative_path'].apply(lambda x: os.path.join(dest_dir, x))

# %%
df.to_csv('ABIDE_I_relative_paths_with_age_sex.csv')

# %%
files = list(df['relative_path'])[0:50]

# %%
for file in files:
    print(os.path.exists(file))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
