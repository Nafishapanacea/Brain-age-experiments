# %%
import os
import subprocess
import torch
from torch.utils.data import DataLoader
from monai import transforms
from monai.data import Dataset
from monai.networks.nets.densenet import DenseNet201

# %%
template_path = '/home/jupyter-nafisha/Brain_age/templates/MNI152_T1_1mm_Brain.nii.gz'
model_path = "/home/jupyter-nafisha/Brain_age/synthstrip.pt"

# %%
# path = '/home/jupyter-nafisha/Brain_age/Abide_IXI_data/abide_10.nii.gz'

# %%
ants_bin = "/home/jupyter-nafisha/Brain_age/ants_2_6_3/ants-2.6.3/bin"
env = os.environ.copy()
env["PATH"] = ants_bin + ":" + env["PATH"]

def preprocessing(input_path, model_path, template_path):
    strip_out = os.path.join('/home/jupyter-nafisha/Brain_age/Temp_output', 'stripped.nii.gz')
    cmd = [
        "/home/jupyter-nafisha/.local/bin/nipreps-synthstrip",
        "-i", input_path,
        "-o", strip_out,
        "--model", model_path
    ]

    result = subprocess.run(cmd, capture_output=True, text=True)
    # result = subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    output_path = '/home/jupyter-nafisha/Brain_age/Temp_output/regis_' 
    reg_cmd = [
        f"{ants_bin}/antsRegistrationSyNQuick.sh",
        "-d", "3",
        "-f", template_path,
        "-m", strip_out,
        "-o", output_path,
        "-n", str(os.cpu_count()),   
        "-t", "a"
    ]
    subprocess.run(reg_cmd, env=env, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    
    return output_path + "Warped.nii.gz"

# %%
def get_inputs(inputs_path: str) -> list:
    
    def get_inputs_from_dir(inputs_path: str) -> list:
        is_nii = lambda f: f.endswith('.nii') or f.endswith('.nii.gz')
        files = os.listdir(inputs_path)
        input_paths = [ os.path.join(inputs_path, f) for f in files if is_nii(f) ]
        return input_paths

    def get_inputs_from_csv(inputs_path: str) -> list:
        with open(inputs_path, 'r') as f:
            return [ p.strip() for p in f.readlines() ]
        
    return get_inputs_from_dir(inputs_path) if os.path.isdir(inputs_path) \
        else get_inputs_from_csv(inputs_path)

transforms_fn = transforms.Compose([
    transforms.CopyItemsD(keys={'scan_path'}, names=['image']),
    transforms.LoadImageD(keys='image'),
    transforms.EnsureChannelFirstD(keys='image', channel_dim='no_channel'),
    transforms.SpacingD(keys='image', pixdim=1.4),
    transforms.ResizeWithPadOrCropD(keys='image', spatial_size=(130, 130, 130), mode='minimum'),
    transforms.ScaleIntensityD(keys='image', minv=0, maxv=1),
    transforms.Lambda(lambda d: d['image']),
])

# %%
# model = DenseNet201(3, 1, 1, dropout_prob=0)
# model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# model = model.to(DEVICE).eval()

# %%
# input_folder = '/home/jupyter-nafisha/Brain_age/stripped'
# input_folder = '/home/jupyter-nafisha/Brain_age/Data'

# input_paths = get_inputs(input_folder)
# if len(input_paths) < 1: 
#     print('No images to process. Exiting.')
#     exit()

# preprocessed_paths = []
# for path in input_paths:
#     out_path= preprocessing(path, model_path, template_path)
#     preprocessed_paths.append(out_path)

# model_path = '/home/jupyter-nafisha/Brain_age/synthba-g.pth'
# DEVICE = 'cpu'
# batch_size = 1

# %%
# model

# %%
# # prepare the dataset
# data = [ { 'scan_path': p } for p in preprocessed_paths ]
# dataset = Dataset(data=data, transform=transforms_fn)    
# loader = DataLoader(dataset=dataset, batch_size=1)

# %%
# brain_age_list = []
# for i, images in enumerate(loader):
#     print(f'processing batch n.{i}')
#     with torch.no_grad():
#         brain_ages = model(images.to(DEVICE))
#         brain_age_list += list(brain_ages.view(-1).cpu().numpy() * 100)
#     break

# %%
ls
# Out:
# Abide_data/                CSVs/                      stripped/
# Abide_inf_using_api.ipynb  inf.ipynb                  synthba-g.pth
# Abide_IXI_data/            parkinson_alzheimer.ipynb  synthstrip.pt
# Alzheimer_ADNI_data/       parkinson_data/            templates/
# Alzheimer_ADNI_data.zip    parkinson_preprocessed/    Temp_output/
# ants_2_6_3/                Register/

# %%
densenet_path = '/home/jupyter-nafisha/Brain_age/synthba-g.pth'
DEVICE = 'cpu'
batch_size = 1

model = DenseNet201(3, 1, 1, dropout_prob=0)
model.load_state_dict(torch.load(densenet_path, map_location=DEVICE))
model = model.to(DEVICE).eval()

# %%
# IXI

# input_folder = '/home/common/IXI-T1'

# input_paths = get_inputs(input_folder)
# if len(input_paths) < 1: 
#     print('No images to process. Exiting.')
#     exit()

# %%
# Abide

import pandas as pd
df= pd.read_csv('/home/jupyter-nafisha/Brain_age/CSVs/ABIDE_I_relative_paths_with_age_sex.csv')
input_paths = list(df['relative_path'])[0:50]

# %%
input_paths
# Out:
# ['/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/CMU_50665/CMU_50665/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Leuven_50707/Leuven_50707/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/OHSU_50160/OHSU_50160/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Yale_50577/Yale_50577/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/SDSU_50198/SDSU_50198/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51081/NYU_51081/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Trinity_50263/Trinity_50263/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/KKI_50790/KKI_50790/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Leuven_50723/Leuven_50723/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Trinity_51140/Trinity_51140/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/OHSU_50158/OHSU_50158/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Yale_50567/Yale_50567/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/KKI_50773/KKI_50773/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/SDSU_50197/SDSU_50197/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/SBL_51566/SBL_51566/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Olin_50112/Olin_50112/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/SDSU_50211/SDSU_50211/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Pitt_50030/Pitt_50030/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51122/NYU_51122/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51067/NYU_51067/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51096/NYU_51096/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/MaxMun_51373/MaxMun_51373/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Trinity_50260/Trinity_50260/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Caltech_51490/Caltech_51490/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/UM_50427/UM_50427/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/UM_50428/UM_50428/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/KKI_50781/KKI_50781/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/MaxMun_51360/MaxMun_51360/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Yale_50565/Yale_50565/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/UM_50334/UM_50334/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51044/NYU_51044/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Pitt_50044/Pitt_50044/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/CMU_50656/CMU_50656/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51084/NYU_51084/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51153/NYU_51153/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Caltech_51480/Caltech_51480/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51069/NYU_51069/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Yale_50556/Yale_50556/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51126/NYU_51126/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/USM_50441/USM_50441/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51151/NYU_51151/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Pitt_50050/Pitt_50050/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/UM_50370/UM_50370/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/KKI_50814/KKI_50814/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/SDSU_50200/SDSU_50200/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/SBL_51562/SBL_51562/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/UM_50391/UM_50391/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/KKI_50778/KKI_50778/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/UM_50371/UM_50371/anat/NIfTI/mprage.nii.gz',
#  '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Stanford_51182/Stanford_51182/anat/NIfTI/mprage.nii.gz']

# %%
# input_folder = '/home/jupyter-nafisha/Brain_age/stripped'

# count=0

brain_age_list = []
full_list = []

for path in input_paths:
    out_path= preprocessing(path, model_path, template_path)

    dataset = Dataset(data= [{ 'scan_path': out_path }], transform=transforms_fn)  
    loader = DataLoader(dataset=dataset, batch_size=1)

    for i, images in enumerate(loader):
        print(f'processing batch n.{i}')
        with torch.no_grad():
            brain_ages = model(images.to(DEVICE))
            brain_age_list += list(brain_ages.view(-1).cpu().numpy() * 100)
            # full_list.append([path, brain_ages.view(-1).cpu().numpy() * 100])
        print(path, brain_ages.view(-1).cpu().numpy() * 100)
    
    # count+=1
    # if count==50:
    #     break
# Out:
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/CMU_50665/CMU_50665/anat/NIfTI/mprage.nii.gz [19.195185]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Leuven_50707/Leuven_50707/anat/NIfTI/mprage.nii.gz [14.458945]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/OHSU_50160/OHSU_50160/anat/NIfTI/mprage.nii.gz [9.833555]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Yale_50577/Yale_50577/anat/NIfTI/mprage.nii.gz [8.316637]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/SDSU_50198/SDSU_50198/anat/NIfTI/mprage.nii.gz [11.6289]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51081/NYU_51081/anat/NIfTI/mprage.nii.gz [6.5459743]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Trinity_50263/Trinity_50263/anat/NIfTI/mprage.nii.gz [26.003466]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/KKI_50790/KKI_50790/anat/NIfTI/mprage.nii.gz [7.6052785]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Leuven_50723/Leuven_50723/anat/NIfTI/mprage.nii.gz [9.782561]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Trinity_51140/Trinity_51140/anat/NIfTI/mprage.nii.gz [15.917299]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/OHSU_50158/OHSU_50158/anat/NIfTI/mprage.nii.gz [3.7983737]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Yale_50567/Yale_50567/anat/NIfTI/mprage.nii.gz [12.242502]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/KKI_50773/KKI_50773/anat/NIfTI/mprage.nii.gz [6.6960974]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/SDSU_50197/SDSU_50197/anat/NIfTI/mprage.nii.gz [14.91304]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/SBL_51566/SBL_51566/anat/NIfTI/mprage.nii.gz [22.776953]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Olin_50112/Olin_50112/anat/NIfTI/mprage.nii.gz [26.913742]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/SDSU_50211/SDSU_50211/anat/NIfTI/mprage.nii.gz [16.675823]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Pitt_50030/Pitt_50030/anat/NIfTI/mprage.nii.gz [18.497757]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51122/NYU_51122/anat/NIfTI/mprage.nii.gz [12.984543]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51067/NYU_51067/anat/NIfTI/mprage.nii.gz [11.309452]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51096/NYU_51096/anat/NIfTI/mprage.nii.gz [10.074217]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/MaxMun_51373/MaxMun_51373/anat/NIfTI/mprage.nii.gz [24.815706]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Trinity_50260/Trinity_50260/anat/NIfTI/mprage.nii.gz [23.622986]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Caltech_51490/Caltech_51490/anat/NIfTI/mprage.nii.gz [27.429089]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/UM_50427/UM_50427/anat/NIfTI/mprage.nii.gz [13.621516]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/UM_50428/UM_50428/anat/NIfTI/mprage.nii.gz [6.6842904]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/KKI_50781/KKI_50781/anat/NIfTI/mprage.nii.gz [6.122825]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/MaxMun_51360/MaxMun_51360/anat/NIfTI/mprage.nii.gz [18.582142]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Yale_50565/Yale_50565/anat/NIfTI/mprage.nii.gz [7.206367]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/UM_50334/UM_50334/anat/NIfTI/mprage.nii.gz [5.42637]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51044/NYU_51044/anat/NIfTI/mprage.nii.gz [5.4306684]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Pitt_50044/Pitt_50044/anat/NIfTI/mprage.nii.gz [11.88005]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/CMU_50656/CMU_50656/anat/NIfTI/mprage.nii.gz [20.58193]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51084/NYU_51084/anat/NIfTI/mprage.nii.gz [4.155437]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51153/NYU_51153/anat/NIfTI/mprage.nii.gz [19.313557]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Caltech_51480/Caltech_51480/anat/NIfTI/mprage.nii.gz [13.832914]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51069/NYU_51069/anat/NIfTI/mprage.nii.gz [4.713621]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Yale_50556/Yale_50556/anat/NIfTI/mprage.nii.gz [9.630942]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51126/NYU_51126/anat/NIfTI/mprage.nii.gz [14.994928]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/USM_50441/USM_50441/anat/NIfTI/mprage.nii.gz [14.954398]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/NYU_51151/NYU_51151/anat/NIfTI/mprage.nii.gz [19.431093]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Pitt_50050/Pitt_50050/anat/NIfTI/mprage.nii.gz [8.072854]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/UM_50370/UM_50370/anat/NIfTI/mprage.nii.gz [10.337129]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/KKI_50814/KKI_50814/anat/NIfTI/mprage.nii.gz [7.8038745]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/SDSU_50200/SDSU_50200/anat/NIfTI/mprage.nii.gz [8.318757]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/SBL_51562/SBL_51562/anat/NIfTI/mprage.nii.gz [19.602365]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/UM_50391/UM_50391/anat/NIfTI/mprage.nii.gz [20.918272]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/KKI_50778/KKI_50778/anat/NIfTI/mprage.nii.gz [7.121397]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/UM_50371/UM_50371/anat/NIfTI/mprage.nii.gz [8.897502]
# processing batch n.0
# /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I/Stanford_51182/Stanford_51182/anat/NIfTI/mprage.nii.gz [5.4922605]

# %%
# brain_age_list
# full_list

# %%
csv_path = '/home/jupyter-nafisha/Brain_age/CSVs/predictions_abide_synthBA_affineFlag.csv'
with open(csv_path, 'w') as csv:
    csv.write("input_id,brainage\n")
    for scan_path, brain_age in zip(input_paths, brain_age_list):
        csv.write(f"{scan_path},{brain_age}\n")

# %%
brain_age_list
# Out:
# [np.float32(19.195185),
#  np.float32(14.458945),
#  np.float32(9.833555),
#  np.float32(8.316637),
#  np.float32(11.6289),
#  np.float32(6.5459743),
#  np.float32(26.003466),
#  np.float32(7.6052785),
#  np.float32(9.782561),
#  np.float32(15.917299),
#  np.float32(3.7983737),
#  np.float32(12.242502),
#  np.float32(6.6960974),
#  np.float32(14.91304),
#  np.float32(22.776953),
#  np.float32(26.913742),
#  np.float32(16.675823),
#  np.float32(18.497757),
#  np.float32(12.984543),
#  np.float32(11.309452),
#  np.float32(10.074217),
#  np.float32(24.815706),
#  np.float32(23.622986),
#  np.float32(27.429089),
#  np.float32(13.621516),
#  np.float32(6.6842904),
#  np.float32(6.122825),
#  np.float32(18.582142),
#  np.float32(7.206367),
#  np.float32(5.42637),
#  np.float32(5.4306684),
#  np.float32(11.88005),
#  np.float32(20.58193),
#  np.float32(4.155437),
#  np.float32(19.313557),
#  np.float32(13.832914),
#  np.float32(4.713621),
#  np.float32(9.630942),
#  np.float32(14.994928),
#  np.float32(14.954398),
#  np.float32(19.431093),
#  np.float32(8.072854),
#  np.float32(10.337129),
#  np.float32(7.8038745),
#  np.float32(8.318757),
#  np.float32(19.602365),
#  np.float32(20.918272),
#  np.float32(7.121397),
#  np.float32(8.897502),
#  np.float32(5.4922605)]

# %%
# import pandas as pd
# csv= pd.read_csv('/home/jupyter-nafisha/Brain_age/CSVs/predictions_abide_synthBA_affineFlag.csv')
# csv= csv.rename(columns={'brainage': 'predicted_brainage'})

# %%
# csv.to_csv('/home/jupyter-nafisha/Brain_age/CSVs/predictions_abide_synthBA_affineFlag.csv', index= False)

# %%
# # creating csv

# csv2= pd.read_csv('/home/jupyter-nafisha/Brain_age/CSVs/ABIDE_I_relative_paths_with_age_sex.csv')
# new_csv= csv.merge(
#     csv2,
#     left_on='input_id',
#     right_on='relative_path',
#     how='inner'
# )
# final= new_csv[['input_id', 'age_at_scan', 'predicted_brainage']]

# %%
# final.to_csv('/home/jupyter-nafisha/Brain_age/CSVs/predictions_abide_synthBA_affineFlag.csv', index= False)

# %% [markdown]
# # MAE calculation- IXI

# %%
import pandas as pd

csv_path = '/home/jupyter-nafisha/Brain_age/Temp_output/prediction_IXI.csv'
pred= pd.read_csv(csv_path)

# %%
# pred['input_id'] = pred['input_id'].str.replace('/home/common/IXI-T1/', '', regex=False)
# pred

# %%
import numpy as np

mae = np.mean(np.abs(pred['actual_age'] - pred['predicted_age']))
print("MAE =", mae)
# Out:
# MAE = 11.860384801605687

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
plt.scatter(pred['actual_age'], pred['predicted_age'], alpha=0.6)

# Add diagonal y=x line
x = np.linspace(pred['actual_age'].min(), pred['actual_age'].max(), 100)
plt.plot(x, x, linestyle='--')

plt.xlabel('Actual Age')
plt.ylabel('Predicted Brain Age')
plt.title('Actual Age vs Predicted Brain Age')
plt.grid(True)
plt.show()

# %%
# making Zip of data for freesurfer

# %%
pwd
# Out:
# '/home/jupyter-nafisha/Brain_age'

# %%
import shutil
dest_dir = '/home/jupyter-nafisha/Brain_age/IXI_data'
for itr, row in final_df.iterrows():
    file_path= os.path.join('/home/common/IXI-T1', row['input_id'])
    shutil.copy(file_path, dest_dir)

# %%
import shutil

dest_dir = '/home/jupyter-nafisha/Brain_age/IXI_data'
zip_path = '/home/jupyter-nafisha/Brain_age/IXI_data'

shutil.make_archive(zip_path, 'zip', dest_dir)
# Out:
# '/home/jupyter-nafisha/Brain_age/IXI_data.zip'

# %% [markdown]
# # MAE calculation- ABIDE

# %%
import pandas as pd
df= pd.read_csv('ABIDE_I_relative_paths_with_age_sex.csv')
df
# Out:
#      Unnamed: 0        subject  \
# 0             0      CMU_50665
# 1             1   Leuven_50707
# 2             2     OHSU_50160
# 3             3     Yale_50577
# 4             4     SDSU_50198
# ..          ...            ...
# 566         566     OHSU_50161
# 567         567  Caltech_51476
# 568         568   MaxMun_51363
# 569         569   MaxMun_51341
# 570         570   Leuven_50742
#
#                                          relative_path  age_at_scan  sex
# 0    /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...        33.00    1
# 1    /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...        22.00    1
# 2    /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...        11.45    1
# 3    /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...        15.25    1
# 4    /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...        15.28    1
# ..                                                 ...          ...  ...
# 566  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...         9.15    1
# 567  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...        39.30    1
# 568  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...        32.00    1
# 569  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...        29.00    1
# 570  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...        16.90    1
#
# [571 rows x 5 columns]

# %%
act_path = '/home/jupyter-nafisha/Brain_age/Temp_output/predictions_abide.csv'
act = pd.read_csv(act_path)
act
# Out:
#                                              input_id   brainage
# 0   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  28.110949
# 1   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  28.141264
# 2   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  20.685213
# 3   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  18.024315
# 4   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  19.132410
# 5   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  25.051373
# 6   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  28.453386
# 7   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  24.538568
# 8   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  23.835234
# 9   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  16.660236
# 10  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...   8.956393
# 11  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  28.791508
# 12  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  21.107277
# 13  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  16.726000
# 14  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  29.765663
# 15  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  30.624168
# 16  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  25.872066
# 17  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  21.894827
# 18  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  24.948082
# 19  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  23.090240
# 20  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  25.340620
# 21  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  28.313789
# 22  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  28.407278
# 23  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  30.804386
# 24  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  27.620121
# 25  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  15.516522
# 26  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  18.715549
# 27  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  18.851641
# 28  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  16.534462
# 29  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  15.936658
# 30  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  16.423740
# 31  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  18.690014
# 32  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  26.525869
# 33  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  11.977745
# 34  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  26.862177
# 35  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  24.905767
# 36  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  15.372040
# 37  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  12.980305
# 38  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  17.199404
# 39  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  18.005108
# 40  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  31.283978
# 41  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  11.268842
# 42  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  20.121082
# 43  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  23.414286
# 44  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  17.384869
# 45  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  34.434216
# 46  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  20.724817
# 47  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  20.435846
# 48  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...  18.230049
# 49  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...   9.781217

# %%
merged = df.merge(
    act,
    left_on='relative_path',
    right_on='input_id',
    how='inner'
)
final= merged[['input_id', 'age_at_scan', 'brainage']]

# %%
# final

# %%
final = final.rename(columns={'age_at_scan':'Actual_age', 'brainage':'Predicted_age'})
final
# Out:
#                                              input_id  Actual_age  \
# 0   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     33.0000
# 1   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     22.0000
# 2   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     11.4500
# 3   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     15.2500
# 4   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     15.2800
# 5   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      8.8200
# 6   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     19.0800
# 7   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      8.8300
# 8   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     13.8000
# 9   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     15.7500
# 10  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     11.5500
# 11  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     17.8300
# 12  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     10.8400
# 13  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     14.9800
# 14  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     41.0000
# 15  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     17.0000
# 16  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     16.1300
# 17  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     25.1200
# 18  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     11.9200
# 19  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     23.6500
# 20  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     13.1800
# 21  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     46.0000
# 22  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     20.3300
# 23  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     44.1000
# 24  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     15.8000
# 25  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     15.5000
# 26  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      9.3000
# 27  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      7.0000
# 28  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     11.0000
# 29  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     11.0000
# 30  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     10.8600
# 31  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     17.1300
# 32  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     28.0000
# 33  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      9.2300
# 34  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     26.1700
# 35  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     20.8000
# 36  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      8.1500
# 37  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     10.6700
# 38  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     16.3100
# 39  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     27.5975
# 40  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     23.0800
# 41  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     14.3700
# 42  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     12.8000
# 43  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      8.4600
# 44  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     13.8800
# 45  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     37.0000
# 46  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     17.2000
# 47  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      9.7300
# 48  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     12.2000
# 49  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...     10.6927
#
#     Predicted_age
# 0       28.110949
# 1       28.141264
# 2       20.685213
# 3       18.024315
# 4       19.132410
# 5       25.051373
# 6       28.453386
# 7       24.538568
# 8       23.835234
# 9       16.660236
# 10       8.956393
# 11      28.791508
# 12      21.107277
# 13      16.726000
# 14      29.765663
# 15      30.624168
# 16      25.872066
# 17      21.894827
# 18      24.948082
# 19      23.090240
# 20      25.340620
# 21      28.313789
# 22      28.407278
# 23      30.804386
# 24      27.620121
# 25      15.516522
# 26      18.715549
# 27      18.851641
# 28      16.534462
# 29      15.936658
# 30      16.423740
# 31      18.690014
# 32      26.525869
# 33      11.977745
# 34      26.862177
# 35      24.905767
# 36      15.372040
# 37      12.980305
# 38      17.199404
# 39      18.005108
# 40      31.283978
# 41      11.268842
# 42      20.121082
# 43      23.414286
# 44      17.384869
# 45      34.434216
# 46      20.724817
# 47      20.435846
# 48      18.230049
# 49       9.781217

# %%
ls
# Out:
# Abide_data/                              IXI_NEW_DF.csv
# Abide_data.zip                           MNI152_T1_1mm_Brain.nii.gz
# ABIDEII-BNI_1_29011.nii.gz               PreProcessing_IXI.ipynb
# Abide.ipynb                              Register/
# ABIDE_I_relative_paths_with_age_sex.csv  stripped/
# Abide_IXI_data/                          synthba-g.pth
# ants_2_6_3/                              synthstrip.pt
# ants-2.6.3-ubuntu-24.04-X64-gcc.zip      templates/
# inf.ipynb                                Temp_output/

# %%
import numpy as np

mae = np.mean(np.abs(final['Actual_age'] - final['Predicted_age']))
print("MAE =", mae)
# Out:
# MAE = 6.958175440887451

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
plt.scatter(final['Actual_age'], final['Predicted_age'], alpha=0.6)

# Add diagonal y=x line
x = np.linspace(final['Actual_age'].min(), final['Actual_age'].max(), 100)
plt.plot(x, x, linestyle='--')

plt.xlabel('Actual Age')
plt.ylabel('Predicted Brain Age')
plt.title('Actual Age vs Predicted Brain Age')
plt.grid(True)
plt.show()

# %%
# Making data copy

# %%
abide_data= pd.read_csv('/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I_relative_paths_with_age_sex.csv')
abide_data
# Out:
#            subject                                      relative_path  \
# 0        CMU_50665       CMU_50665/CMU_50665/anat/NIfTI/mprage.nii.gz
# 1     Leuven_50707  Leuven_50707/Leuven_50707/anat/NIfTI/mprage.ni...
# 2       OHSU_50160     OHSU_50160/OHSU_50160/anat/NIfTI/mprage.nii.gz
# 3       Yale_50577     Yale_50577/Yale_50577/anat/NIfTI/mprage.nii.gz
# 4       SDSU_50198     SDSU_50198/SDSU_50198/anat/NIfTI/mprage.nii.gz
# ..             ...                                                ...
# 566     OHSU_50161     OHSU_50161/OHSU_50161/anat/NIfTI/mprage.nii.gz
# 567  Caltech_51476  Caltech_51476/Caltech_51476/anat/NIfTI/mprage....
# 568   MaxMun_51363  MaxMun_51363/MaxMun_51363/anat/NIfTI/mprage.ni...
# 569   MaxMun_51341  MaxMun_51341/MaxMun_51341/anat/NIfTI/mprage.ni...
# 570   Leuven_50742  Leuven_50742/Leuven_50742/anat/NIfTI/mprage.ni...
#
#      age_at_scan  sex
# 0          33.00    1
# 1          22.00    1
# 2          11.45    1
# 3          15.25    1
# 4          15.28    1
# ..           ...  ...
# 566         9.15    1
# 567        39.30    1
# 568        32.00    1
# 569        29.00    1
# 570        16.90    1
#
# [571 rows x 4 columns]

# %%
import os
import shutil

src_root = '/home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE_I'
dest_root = '/home/jupyter-nafisha/Brain_age/Abide_data'

count = 0

for itr, row in abide_data.iterrows():
    rel_path = row['relative_path']  
    src_path = os.path.join(src_root, rel_path)
    dest_path = os.path.join(dest_root, rel_path)

    # copy only if source exists
    if os.path.exists(src_path):
        
        # now create folders
        os.makedirs(os.path.dirname(dest_path), exist_ok=True)
        
        shutil.copy2(src_path, dest_path)
        count += 1
        # print("Copied:", count, src_path)
        if count == 50:
            break

    else:
        print("MISSING:", src_path)

# %%
zip_path= '/home/jupyter-nafisha/Brain_age/Abide_data'
shutil.make_archive(zip_path, 'zip', dest_root)
# Out:
# '/home/jupyter-nafisha/Brain_age/Abide_data.zip'

# %%
path = '/home/jupyter-nafisha/Brain_age/Temp_output/predictions_abide.csv'
data= pd.read_csv(path)

# %%
# data

# %% [markdown]
# # IXI- scanner-based MAE

# %%
import pandas as pd
csv_path= '/home/jupyter-nafisha/Brain_age/Temp_output/prediction_IXI.csv'

data= pd.read_csv(csv_path)

# %%
data
# Out:
#                       input_id  actual_age  predicted_age
# 0   IXI585-Guys-1130-T1.nii.gz   28.120465      30.212820
# 1   IXI358-Guys-0919-T1.nii.gz   62.061602      40.060078
# 2     IXI296-HH-1970-T1.nii.gz   63.972621      51.119190
# 3    IXI306-IOP-0867-T1.nii.gz   30.182067      23.786682
# 4     IXI211-HH-1568-T1.nii.gz   55.118412      39.780205
# 5   IXI143-Guys-0785-T1.nii.gz   31.956194      29.320744
# 6   IXI227-Guys-0813-T1.nii.gz   67.055441      34.945030
# 7   IXI379-Guys-0943-T1.nii.gz   66.907598      44.474476
# 8   IXI145-Guys-0781-T1.nii.gz   49.385353      39.631454
# 9   IXI236-Guys-0817-T1.nii.gz   25.713895      30.783133
# 10  IXI247-Guys-0838-T1.nii.gz   29.817933      27.921339
# 11    IXI131-HH-1527-T1.nii.gz   45.229295      32.345642
# 12  IXI246-Guys-0840-T1.nii.gz   42.220397      28.861847
# 13   IXI372-IOP-0971-T1.nii.gz   29.256674      28.237963
# 14    IXI174-HH-1571-T1.nii.gz   63.096509      58.753693
# 15  IXI397-Guys-0953-T1.nii.gz   51.657769      32.351662
# 16  IXI450-Guys-1093-T1.nii.gz   68.509240      55.291801
# 17    IXI163-HH-1621-T1.nii.gz   48.052019      32.143452
# 18    IXI165-HH-1589-T1.nii.gz   24.375086      19.549244
# 19    IXI126-HH-1437-T1.nii.gz   57.221081      44.285843
# 20    IXI465-HH-2176-T1.nii.gz   69.281314      61.602829
# 21  IXI109-Guys-0732-T1.nii.gz   36.468172      28.024822
# 22   IXI395-IOP-0969-T1.nii.gz   45.032170      26.037741
# 23  IXI587-Guys-1128-T1.nii.gz   33.593429      30.151091
# 24   IXI541-IOP-1146-T1.nii.gz   36.421629      23.925915
# 25    IXI586-HH-2451-T1.nii.gz   34.365503      20.406342
# 26   IXI434-IOP-1010-T1.nii.gz   67.241615      32.407127
# 27    IXI436-HH-2153-T1.nii.gz   28.347707      26.024651
# 28    IXI242-HH-1722-T1.nii.gz   31.370294      36.128662
# 29    IXI396-HH-2115-T1.nii.gz   53.566051      38.527462
# 30    IXI256-HH-1723-T1.nii.gz   27.383984      27.418116
# 31  IXI196-Guys-0805-T1.nii.gz   29.114305      26.977911
# 32  IXI422-Guys-1071-T1.nii.gz   37.097878      30.525837
# 33    IXI257-HH-1724-T1.nii.gz   69.546886      74.991982
# 34  IXI177-Guys-0831-T1.nii.gz   34.288843      33.049240
# 35  IXI644-Guys-1121-T1.nii.gz   56.873374      32.421379
# 36   IXI231-IOP-0866-T1.nii.gz   58.992471      40.559189
# 37    IXI385-HH-2078-T1.nii.gz   64.646133      59.330471
# 38  IXI098-Guys-0745-T1.nii.gz   29.730322      23.221075
# 39  IXI652-Guys-1116-T1.nii.gz   42.989733      31.126680
# 40  IXI409-Guys-0960-T1.nii.gz   70.951403      42.937012
# 41  IXI428-Guys-0996-T1.nii.gz   55.540041      29.913906
# 42  IXI210-Guys-0856-T1.nii.gz   69.325120      52.307243
# 43  IXI651-Guys-1118-T1.nii.gz   50.395619      28.374695
# 44   IXI378-IOP-0972-T1.nii.gz   38.839151      32.146187

# %%
df_guys = data[data['input_id'].str.contains('guys', case=False, na=False)]
df_hh   = data[data['input_id'].str.contains('HH', case=False, na=False)]
df_iop  = data[data['input_id'].str.contains('IOP', case=False, na=False)]

# %%
len(df_guys), len(df_hh), len(df_iop)
# Out:
# (23, 15, 7)

# %%
df_guys
df_hh
df_iop
# Out:
#                      input_id  actual_age  predicted_age
# 3   IXI306-IOP-0867-T1.nii.gz   30.182067      23.786682
# 13  IXI372-IOP-0971-T1.nii.gz   29.256674      28.237963
# 22  IXI395-IOP-0969-T1.nii.gz   45.032170      26.037741
# 24  IXI541-IOP-1146-T1.nii.gz   36.421629      23.925915
# 26  IXI434-IOP-1010-T1.nii.gz   67.241615      32.407127
# 36  IXI231-IOP-0866-T1.nii.gz   58.992471      40.559189
# 44  IXI378-IOP-0972-T1.nii.gz   38.839151      32.146187

# %%
mae_guys = np.mean(np.abs(df_guys['actual_age'] - df_guys['predicted_age']))
print("MAE (IOP):", mae_guys)
# Out:
# MAE (IOP): 13.096175548057278

# %%
mae_hh = np.mean(np.abs(df_hh['actual_age'] - df_hh['predicted_age']))
print("MAE (IOP):", mae_hh)
# Out:
# MAE (IOP): 8.909353664812176

# %%
import numpy as np

mae_iop = np.mean(np.abs(df_iop['actual_age'] - df_iop['predicted_age']))
print("MAE (IOP):", mae_iop)
# Out:
# MAE (IOP): 14.123567642107982

# %%
import nibabel as nib
img= nib.load('/home/jupyter-nafisha/Brain_age/stripped/IXI_28.nii.gz')

# %%
img.shape
# Out:
# (256, 256, 150)

# %% [markdown]
# # abide_new

# %%
import pandas as pd
csv= pd.read_csv('/home/jupyter-nafisha/Brain_age/CSVs/predictions_abide_synthBA_affineFlag.csv')

# %%
csv
# Out:
#                                              input_id  age_at_scan  \
# 0   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      33.0000
# 1   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      22.0000
# 2   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      11.4500
# 3   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      15.2500
# 4   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      15.2800
# 5   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...       8.8200
# 6   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      19.0800
# 7   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...       8.8300
# 8   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      13.8000
# 9   /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      15.7500
# 10  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      11.5500
# 11  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      17.8300
# 12  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      10.8400
# 13  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      14.9800
# 14  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      41.0000
# 15  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      17.0000
# 16  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      16.1300
# 17  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      25.1200
# 18  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      11.9200
# 19  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      23.6500
# 20  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      13.1800
# 21  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      46.0000
# 22  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      20.3300
# 23  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      44.1000
# 24  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      15.8000
# 25  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      15.5000
# 26  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...       9.3000
# 27  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...       7.0000
# 28  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      11.0000
# 29  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      11.0000
# 30  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      10.8600
# 31  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      17.1300
# 32  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      28.0000
# 33  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...       9.2300
# 34  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      26.1700
# 35  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      20.8000
# 36  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...       8.1500
# 37  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      10.6700
# 38  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      16.3100
# 39  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      27.5975
# 40  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      23.0800
# 41  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      14.3700
# 42  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      12.8000
# 43  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...       8.4600
# 44  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      13.8800
# 45  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      37.0000
# 46  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      17.2000
# 47  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...       9.7300
# 48  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      12.2000
# 49  /home/common/ABIDE/ABIDE_DATA/ABIDE_DATA/ABIDE...      10.6927
#
#     predicted_brainage
# 0            19.195185
# 1            14.458945
# 2             9.833555
# 3             8.316637
# 4            11.628900
# 5             6.545974
# 6            26.003466
# 7             7.605278
# 8             9.782561
# 9            15.917299
# 10            3.798374
# 11           12.242502
# 12            6.696097
# 13           14.913040
# 14           22.776953
# 15           26.913742
# 16           16.675823
# 17           18.497757
# 18           12.984543
# 19           11.309452
# 20           10.074217
# 21           24.815706
# 22           23.622986
# 23           27.429089
# 24           13.621516
# 25            6.684290
# 26            6.122825
# 27           18.582142
# 28            7.206367
# 29            5.426370
# 30            5.430668
# 31           11.880050
# 32           20.581930
# 33            4.155437
# 34           19.313557
# 35           13.832914
# 36            4.713621
# 37            9.630942
# 38           14.994928
# 39           14.954398
# 40           19.431093
# 41            8.072854
# 42           10.337129
# 43            7.803874
# 44            8.318757
# 45           19.602365
# 46           20.918272
# 47            7.121397
# 48            8.897502
# 49            5.492260

# %%
import numpy as np

mae = np.mean(np.abs(csv['age_at_scan'] - csv['predicted_brainage']))
print("MAE =", mae)
# Out:
# MAE = 6.001424049667358

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
plt.scatter(csv['age_at_scan'], csv['predicted_brainage'], alpha=0.6)

# Add diagonal y=x line
x = np.linspace(csv['age_at_scan'].min(), csv['age_at_scan'].max(), 100)
plt.plot(x, x, linestyle='--')

plt.xlabel('Actual Age')
plt.ylabel('Predicted Brain Age')
plt.title('Actual Age vs Predicted Brain Age')
plt.grid(True)
plt.show()
