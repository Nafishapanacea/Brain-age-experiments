# %% [markdown]
# # parkinson csv

# %%
Park_path= '/home/jupyter-nafisha/Brain_age/CSVs/PARKINSON_complete.csv'

# %%
import pandas as pd
park_data= pd.read_csv(Park_path)
park_data
# Out:
#                                               xml_file  subject_id  image_uid  \
# 0          PPMI_3763_MPRAGE_GRAPPA_S212783_I414635.xml        3763     414635
# 1    PPMI_101799_SAG_3D_T1_FSPGR_S1155619_I1616218.xml      101799    1616218
# 2          PPMI_3567_MPRAGE_GRAPPA_S171176_I340732.xml        3567     340732
# 3          PPMI_3323_MPRAGE_GRAPPA_S501591_I778975.xml        3323     778975
# 4          PPMI_3167_MPRAGE_GRAPPA_S124453_I259601.xml        3167     259601
# ..                                                 ...         ...        ...
# 619      PPMI_51731_MPRAGE_GRAPPA_S989182_I1393697.xml       51731    1393697
# 620           PPMI_179894_MPRAGE_S1198540_I1670592.xml      179894    1670592
# 621      PPMI_53339_MPRAGE_GRAPPA_S968474_I1351004.xml       53339    1351004
# 622        PPMI_3834_MPRAGE_GRAPPA_S248505_I473096.xml        3834     473096
# 623   PPMI_175837_3D_T1-weighted_S1207183_I1680902.xml      175837    1680902
#
#                                   matched_image_folder    age sex  \
# 0    /home/omen/Documents/Megha/PARKINSONS_DICOM_DA...  61.45   M
# 1    /home/omen/Documents/Megha/PARKINSONS_DICOM_DA...  62.94   M
# 2    /home/omen/Documents/Megha/PARKINSONS_DICOM_DA...  66.80   F
# 3    /home/omen/Documents/Megha/PARKINSONS_DICOM_DA...  73.34   M
# 4    /home/omen/Documents/Megha/PARKINSONS_DICOM_DA...  59.41   F
# ..                                                 ...    ...  ..
# 619  /home/omen/Documents/Megha/PARKINSONS_DICOM_DA...  74.84   F
# 620  /home/omen/Documents/Megha/PARKINSONS_DICOM_DA...  55.08   M
# 621  /home/omen/Documents/Megha/PARKINSONS_DICOM_DA...  60.41   F
# 622  /home/omen/Documents/Megha/PARKINSONS_DICOM_DA...  70.62   M
# 623  /home/omen/Documents/Megha/PARKINSONS_DICOM_DA...  51.75   M
#
#                  file_path
# 0       3763_414635.nii.gz
# 1    101799_1616218.nii.gz
# 2       3567_340732.nii.gz
# 3       3323_778975.nii.gz
# 4       3167_259601.nii.gz
# ..                     ...
# 619   51731_1393697.nii.gz
# 620  179894_1670592.nii.gz
# 621   53339_1351004.nii.gz
# 622     3834_473096.nii.gz
# 623  175837_1680902.nii.gz
#
# [624 rows x 7 columns]

# %%
park_data["file_path"] = (
    park_data["subject_id"].astype(str)
    + "_"
    + park_data["image_uid"].astype(str)
    + ".nii.gz"
)

# %%
filtered_data= park_data.iloc[0:50]

# %%
# filtered_data

# %%
filtered_data.to_csv('/home/jupyter-nafisha/Brain_age/CSVs/PARKINSON_filtered.csv', index=False)

# %% [markdown]
# ##### parkinson xml

# %%
import pandas as pd
df= pd.read_csv('/home/jupyter-nafisha/Brain_age/CSVs/PARKINSON_filtered.csv')

# %%
filtered= df[['file_path', 'age', 'sex']]
filtered
# Out:
#                 file_path    age sex
# 0      3763_414635.nii.gz  61.45   M
# 1   101799_1616218.nii.gz  62.94   M
# 2      3567_340732.nii.gz  66.80   F
# 3      3323_778975.nii.gz  73.34   M
# 4      3167_259601.nii.gz  59.41   F
# 5      3586_395438.nii.gz  63.94   M
# 6      3130_355961.nii.gz  43.87   M
# 7      3321_374717.nii.gz  70.78   F
# 8      3780_387327.nii.gz  71.05   F
# 9      4013_344310.nii.gz  65.26   M
# 10     4038_367447.nii.gz  70.80   F
# 11     3327_362472.nii.gz  54.35   F
# 12     3778_738222.nii.gz  55.86   F
# 13     3365_344350.nii.gz  49.93   M
# 14     3591_373009.nii.gz  62.73   M
# 15   50027_1225075.nii.gz  63.78   M
# 16     3122_382285.nii.gz  63.15   M
# 17     3760_287999.nii.gz  68.52   M
# 18     3105_372312.nii.gz  70.59   M
# 19     3556_307294.nii.gz  66.62   M
# 20     3364_334595.nii.gz  40.23   F
# 21  141696_1701905.nii.gz  52.83   M
# 22     3564_315632.nii.gz  70.01   M
# 23     3830_357616.nii.gz  51.47   F
# 24  149516_1652961.nii.gz  61.99   M
# 25     3332_378541.nii.gz  74.07   M
# 26  219409_1706817.nii.gz  51.13   F
# 27  144254_1701946.nii.gz  73.83   M
# 28     3808_402072.nii.gz  59.47   M
# 29     3868_402280.nii.gz  70.32   M
# 30     4029_344323.nii.gz  48.76   M
# 31  115448_1537606.nii.gz  68.28   M
# 32     3829_466899.nii.gz  69.35   F
# 33     3308_275561.nii.gz  67.25   M
# 34     3113_337507.nii.gz  60.25   F
# 35     3781_440238.nii.gz  74.02   M
# 36   40534_1224288.nii.gz  68.99   M
# 37    3869_1362356.nii.gz  42.55   M
# 38     3775_757816.nii.gz  66.96   M
# 39     3593_507401.nii.gz  57.42   F
# 40  121109_1642716.nii.gz  56.64   F
# 41     3311_287902.nii.gz  74.58   M
# 42     3869_415746.nii.gz  39.58   M
# 43     3125_387309.nii.gz  47.00   M
# 44     4001_397637.nii.gz  51.86   M
# 45     4110_364078.nii.gz  70.92   M
# 46     3366_397621.nii.gz  63.36   M
# 47   40534_1002617.nii.gz  66.99   M
# 48     3835_373039.nii.gz  71.64   M
# 49     3131_367286.nii.gz  71.21   M

# %%
files_to_remove= ['149516_1652961.nii.gz', '115448_1537606.nii.gz']

filtered = filtered[~filtered['file_path'].isin(files_to_remove)]
filtered
# Out:
#                 file_path    age sex
# 0      3763_414635.nii.gz  61.45   M
# 1   101799_1616218.nii.gz  62.94   M
# 2      3567_340732.nii.gz  66.80   F
# 3      3323_778975.nii.gz  73.34   M
# 4      3167_259601.nii.gz  59.41   F
# 5      3586_395438.nii.gz  63.94   M
# 6      3130_355961.nii.gz  43.87   M
# 7      3321_374717.nii.gz  70.78   F
# 8      3780_387327.nii.gz  71.05   F
# 9      4013_344310.nii.gz  65.26   M
# 10     4038_367447.nii.gz  70.80   F
# 11     3327_362472.nii.gz  54.35   F
# 12     3778_738222.nii.gz  55.86   F
# 13     3365_344350.nii.gz  49.93   M
# 14     3591_373009.nii.gz  62.73   M
# 15   50027_1225075.nii.gz  63.78   M
# 16     3122_382285.nii.gz  63.15   M
# 17     3760_287999.nii.gz  68.52   M
# 18     3105_372312.nii.gz  70.59   M
# 19     3556_307294.nii.gz  66.62   M
# 20     3364_334595.nii.gz  40.23   F
# 21  141696_1701905.nii.gz  52.83   M
# 22     3564_315632.nii.gz  70.01   M
# 23     3830_357616.nii.gz  51.47   F
# 25     3332_378541.nii.gz  74.07   M
# 26  219409_1706817.nii.gz  51.13   F
# 27  144254_1701946.nii.gz  73.83   M
# 28     3808_402072.nii.gz  59.47   M
# 29     3868_402280.nii.gz  70.32   M
# 30     4029_344323.nii.gz  48.76   M
# 32     3829_466899.nii.gz  69.35   F
# 33     3308_275561.nii.gz  67.25   M
# 34     3113_337507.nii.gz  60.25   F
# 35     3781_440238.nii.gz  74.02   M
# 36   40534_1224288.nii.gz  68.99   M
# 37    3869_1362356.nii.gz  42.55   M
# 38     3775_757816.nii.gz  66.96   M
# 39     3593_507401.nii.gz  57.42   F
# 40  121109_1642716.nii.gz  56.64   F
# 41     3311_287902.nii.gz  74.58   M
# 42     3869_415746.nii.gz  39.58   M
# 43     3125_387309.nii.gz  47.00   M
# 44     4001_397637.nii.gz  51.86   M
# 45     4110_364078.nii.gz  70.92   M
# 46     3366_397621.nii.gz  63.36   M
# 47   40534_1002617.nii.gz  66.99   M
# 48     3835_373039.nii.gz  71.64   M
# 49     3131_367286.nii.gz  71.21   M

# %%
filtered['sex'] = filtered['sex'].map({'M': 1, 'F': 2})
# Out:
# /tmp/ipykernel_525365/476915371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['sex'] = filtered['sex'].map({'M': 1, 'F': 2})

# %%
filtered['file_path']= filtered['file_path'].str.replace('.nii.gz','_Warped.nii.gz')
# Out:
# /tmp/ipykernel_525365/2653560715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['file_path']= filtered['file_path'].str.replace('.nii.gz','_Warped.nii.gz')

# %%
filtered
# Out:
#                        file_path    age  sex
# 0      3763_414635_Warped.nii.gz  61.45    1
# 1   101799_1616218_Warped.nii.gz  62.94    1
# 2      3567_340732_Warped.nii.gz  66.80    2
# 3      3323_778975_Warped.nii.gz  73.34    1
# 4      3167_259601_Warped.nii.gz  59.41    2
# 5      3586_395438_Warped.nii.gz  63.94    1
# 6      3130_355961_Warped.nii.gz  43.87    1
# 7      3321_374717_Warped.nii.gz  70.78    2
# 8      3780_387327_Warped.nii.gz  71.05    2
# 9      4013_344310_Warped.nii.gz  65.26    1
# 10     4038_367447_Warped.nii.gz  70.80    2
# 11     3327_362472_Warped.nii.gz  54.35    2
# 12     3778_738222_Warped.nii.gz  55.86    2
# 13     3365_344350_Warped.nii.gz  49.93    1
# 14     3591_373009_Warped.nii.gz  62.73    1
# 15   50027_1225075_Warped.nii.gz  63.78    1
# 16     3122_382285_Warped.nii.gz  63.15    1
# 17     3760_287999_Warped.nii.gz  68.52    1
# 18     3105_372312_Warped.nii.gz  70.59    1
# 19     3556_307294_Warped.nii.gz  66.62    1
# 20     3364_334595_Warped.nii.gz  40.23    2
# 21  141696_1701905_Warped.nii.gz  52.83    1
# 22     3564_315632_Warped.nii.gz  70.01    1
# 23     3830_357616_Warped.nii.gz  51.47    2
# 25     3332_378541_Warped.nii.gz  74.07    1
# 26  219409_1706817_Warped.nii.gz  51.13    2
# 27  144254_1701946_Warped.nii.gz  73.83    1
# 28     3808_402072_Warped.nii.gz  59.47    1
# 29     3868_402280_Warped.nii.gz  70.32    1
# 30     4029_344323_Warped.nii.gz  48.76    1
# 32     3829_466899_Warped.nii.gz  69.35    2
# 33     3308_275561_Warped.nii.gz  67.25    1
# 34     3113_337507_Warped.nii.gz  60.25    2
# 35     3781_440238_Warped.nii.gz  74.02    1
# 36   40534_1224288_Warped.nii.gz  68.99    1
# 37    3869_1362356_Warped.nii.gz  42.55    1
# 38     3775_757816_Warped.nii.gz  66.96    1
# 39     3593_507401_Warped.nii.gz  57.42    2
# 40  121109_1642716_Warped.nii.gz  56.64    2
# 41     3311_287902_Warped.nii.gz  74.58    1
# 42     3869_415746_Warped.nii.gz  39.58    1
# 43     3125_387309_Warped.nii.gz  47.00    1
# 44     4001_397637_Warped.nii.gz  51.86    1
# 45     4110_364078_Warped.nii.gz  70.92    1
# 46     3366_397621_Warped.nii.gz  63.36    1
# 47   40534_1002617_Warped.nii.gz  66.99    1
# 48     3835_373039_Warped.nii.gz  71.64    1
# 49     3131_367286_Warped.nii.gz  71.21    1

# %%
filtered.to_excel('/home/jupyter-nafisha/Brain_age/CSVs/PARKINSON_filtered.xlsx', index= False)

# %% [markdown]
# ### inference

# %%
import os
import subprocess
import torch
from torch.utils.data import DataLoader
from monai import transforms
from monai.data import Dataset
from monai.networks.nets.densenet import DenseNet201

# %%
template_path = '/home/jupyter-nafisha/Brain_age/templates/MNI152_T1_1mm_Brain.nii.gz'
model_path = "/home/jupyter-nafisha/Brain_age/synthstrip.pt"

# %%
ants_bin = "/home/jupyter-nafisha/Brain_age/ants_2_6_3/ants-2.6.3/bin"
env = os.environ.copy()
env["PATH"] = ants_bin + ":" + env["PATH"]

def preprocessing(input_path, model_path, template_path):
    strip_out = os.path.join('/home/jupyter-nafisha/Brain_age/parkinson_preprocessed/stripped', input_path)
    input_path= os.path.join('/home/jupyter-nafisha/Brain_age/parkinson_data', input_path)
    
    cmd = [
        "/home/jupyter-nafisha/.local/bin/nipreps-synthstrip",
        "-i", input_path,
        "-o", strip_out,
        "--model", model_path
    ]
    if not os.path.exists(strip_out):
        result = subprocess.run(cmd, capture_output=True, text=True)
        # print("SynthStrip STDOUT:\n", result.stdout)
        # print("SynthStrip STDERR:\n", result.stderr)
    # result = subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # print(cmd)

    base_name = os.path.basename(input_path).replace(".nii.gz", "").replace(".nii", "")
    output_path = os.path.join('/home/jupyter-nafisha/Brain_age/parkinson_preprocessed/registered', base_name +'_')
    reg_cmd = [
        f"{ants_bin}/antsRegistrationSyNQuick.sh",
        "-d", "3",
        "-f", template_path,
        "-m", strip_out,
        "-o", output_path,
        "-n", str(os.cpu_count()),   
        "-t", "a"
    ]
    if not os.path.exists(output_path + "Warped.nii.gz"):
        subprocess.run(reg_cmd, env=env, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        # result = subprocess.run(reg_cmd, env=env, capture_output=True, text=True)
        # print("ANTS STDOUT:\n", result.stdout)
        # print("ANTS STDERR:\n", result.stderr)


        
    # print(reg_cmd)
    # print(os.path.exists(input_path))
    # print(os.path.exists(strip_out))
    # print(os.path.exists(output_path))
    # print(strip_out, output_path)
    
    return output_path + "Warped.nii.gz"

# %%
def get_inputs(inputs_path: str) -> list:
    
    def get_inputs_from_dir(inputs_path: str) -> list:
        is_nii = lambda f: f.endswith('.nii') or f.endswith('.nii.gz')
        files = os.listdir(inputs_path)
        input_paths = [ os.path.join(inputs_path, f) for f in files if is_nii(f) ]
        return input_paths

    def get_inputs_from_csv(inputs_path: str) -> list:
        with open(inputs_path, 'r') as f:
            return [ p.strip() for p in f.readlines() ]
        
    return get_inputs_from_dir(inputs_path) if os.path.isdir(inputs_path) \
        else get_inputs_from_csv(inputs_path)

transforms_fn = transforms.Compose([
    transforms.CopyItemsD(keys={'scan_path'}, names=['image']),
    transforms.LoadImageD(keys='image'),
    transforms.EnsureChannelFirstD(keys='image', channel_dim='no_channel'),
    transforms.SpacingD(keys='image', pixdim=1.4),
    transforms.ResizeWithPadOrCropD(keys='image', spatial_size=(130, 130, 130), mode='minimum'),
    transforms.ScaleIntensityD(keys='image', minv=0, maxv=1),
    transforms.Lambda(lambda d: d['image']),
])

# %%
densenet_path = '/home/jupyter-nafisha/Brain_age/synthba-g.pth'
DEVICE = 'cpu'
batch_size = 1

model = DenseNet201(3, 1, 1, dropout_prob=0)
model.load_state_dict(torch.load(densenet_path, map_location=DEVICE))
model = model.to(DEVICE).eval()

# %%
import pandas as pd
data= pd.read_csv('/home/jupyter-nafisha/Brain_age/CSVs/PARKINSON_filtered.csv')
input_paths= list(data['file_path'])

# %%
input_paths = [p for p in input_paths if p != '149516_1652961.nii.gz']
input_paths = [p for p in input_paths if p != '115448_1537606.nii.gz']
len(input_paths)
# Out:
# 48

# %%
# cmd = [
#     "/home/jupyter-nafisha/.local/bin/nipreps-synthstrip",
#     "-i", '/home/jupyter-nafisha/Brain_age/parkinson_data/149516_1652961.nii.gz',
#     "-o", '/home/jupyter-nafisha/Brain_age/parkinson_preprocessed/stripped/149516_1652961.nii.gz',
#     "--model", model_path
# ]
# # if not os.path.exists(strip_out):
# result = subprocess.run(cmd, capture_output=True, text=True)

# %%
# os.path.exists('/home/jupyter-nafisha/Brain_age/parkinson_preprocessed/stripped/149516_1652961.nii.gz')

# %%
brain_age_list = []
full_list = []

for path in input_paths:
    out_path= preprocessing(path, model_path, template_path)

    dataset = Dataset(data= [{ 'scan_path': out_path }], transform=transforms_fn)  
    loader = DataLoader(dataset=dataset, batch_size=1)

    for i, images in enumerate(loader):
        print(f'processing batch n.{i}')
        with torch.no_grad():
            brain_ages = model(images.to(DEVICE))
            brain_age_list += list(brain_ages.view(-1).cpu().numpy() * 100)
            # full_list.append([path, brain_ages.view(-1).cpu().numpy() * 100])
        print(path, brain_ages.view(-1).cpu().numpy() * 100)
    # break
# Out:
# processing batch n.0
# 3763_414635.nii.gz [61.430573]
# processing batch n.0
# 101799_1616218.nii.gz [61.850063]
# processing batch n.0
# 3567_340732.nii.gz [60.57269]
# processing batch n.0
# 3323_778975.nii.gz [76.458015]
# processing batch n.0
# 3167_259601.nii.gz [34.665794]
# processing batch n.0
# 3586_395438.nii.gz [61.69234]
# processing batch n.0
# 3130_355961.nii.gz [40.011467]
# processing batch n.0
# 3321_374717.nii.gz [79.01013]
# processing batch n.0
# 3780_387327.nii.gz [67.19305]
# processing batch n.0
# 4013_344310.nii.gz [56.351566]
# processing batch n.0
# 4038_367447.nii.gz [68.72806]
# processing batch n.0
# 3327_362472.nii.gz [45.793926]
# processing batch n.0
# 3778_738222.nii.gz [60.25961]
# processing batch n.0
# 3365_344350.nii.gz [58.587734]
# processing batch n.0
# 3591_373009.nii.gz [48.482243]
# processing batch n.0
# 50027_1225075.nii.gz [62.35821]
# processing batch n.0
# 3122_382285.nii.gz [67.622894]
# processing batch n.0
# 3760_287999.nii.gz [50.528793]
# processing batch n.0
# 3105_372312.nii.gz [78.08673]
# processing batch n.0
# 3556_307294.nii.gz [65.6855]
# processing batch n.0
# 3364_334595.nii.gz [27.202425]
# processing batch n.0
# 141696_1701905.nii.gz [44.427498]
# processing batch n.0
# 3564_315632.nii.gz [65.036736]
# processing batch n.0
# 3830_357616.nii.gz [59.6819]
# processing batch n.0
# 3332_378541.nii.gz [60.104733]
# processing batch n.0
# 219409_1706817.nii.gz [39.62917]
# processing batch n.0
# 144254_1701946.nii.gz [64.88778]
# processing batch n.0
# 3808_402072.nii.gz [60.072536]
# processing batch n.0
# 3868_402280.nii.gz [83.915695]
# processing batch n.0
# 4029_344323.nii.gz [35.33332]
# processing batch n.0
# 3829_466899.nii.gz [66.955154]
# processing batch n.0
# 3308_275561.nii.gz [59.074795]
# processing batch n.0
# 3113_337507.nii.gz [66.192474]
# processing batch n.0
# 3781_440238.nii.gz [71.097336]
# processing batch n.0
# 40534_1224288.nii.gz [67.40537]
# processing batch n.0
# 3869_1362356.nii.gz [37.15694]
# processing batch n.0
# 3775_757816.nii.gz [58.360203]
# processing batch n.0
# 3593_507401.nii.gz [57.522877]
# processing batch n.0
# 121109_1642716.nii.gz [52.882774]
# processing batch n.0
# 3311_287902.nii.gz [75.385605]
# processing batch n.0
# 3869_415746.nii.gz [37.58221]
# processing batch n.0
# 3125_387309.nii.gz [29.936972]
# processing batch n.0
# 4001_397637.nii.gz [50.758533]
# processing batch n.0
# 4110_364078.nii.gz [69.1748]
# processing batch n.0
# 3366_397621.nii.gz [49.58117]
# processing batch n.0
# 40534_1002617.nii.gz [64.958916]
# processing batch n.0
# 3835_373039.nii.gz [63.690556]
# processing batch n.0
# 3131_367286.nii.gz [76.87853]

# %%
csv_path = '/home/jupyter-nafisha/Brain_age/CSVs/parkinson_synthBA.csv'
with open(csv_path, 'w') as csv:
    csv.write("input_id,brainage\n")
    for scan_path, brain_age in zip(input_paths, brain_age_list):
        csv.write(f"{scan_path},{brain_age}\n")

# %% [markdown]
# ### MAE

# %%
import pandas as pd

pred_path= '/home/jupyter-nafisha/Brain_age/CSVs/parkinson_synthBA.csv'
act_path= '/home/jupyter-nafisha/Brain_age/CSVs/PARKINSON_filtered.csv'
# final= merged['input_id', ]

pred= pd.read_csv(pred_path)
pred= pred.rename(columns={'brainage':'predicted_brainage'})
pred.to_csv(pred_path, index= False)

act= pd.read_csv(act_path)

merged= pred.merge(
    act,
    left_on= 'input_id',
    right_on= 'file_path',
    how= 'inner'
)

final= merged[['input_id', 'age' , 'predicted_brainage']]

# %%
final.to_csv(pred_path, index= False)

# %%
import numpy as np

mae = np.mean(np.abs(final['age'] - final['predicted_brainage']))
print("MAE =", mae)
# Out:
# MAE = 6.671105724970498

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
plt.scatter(final['age'], final['predicted_brainage'], alpha=0.6)

# Add diagonal y=x line
x = np.linspace(final['age'].min(), final['age'].max(), 100)
plt.plot(x, x, linestyle='--')

plt.xlabel('Actual Age')
plt.ylabel('Predicted Brain Age')
plt.title('Actual Age vs Predicted Brain Age')
plt.grid(True)
plt.show()

# %% [markdown]
# # Alzheimer CSV

# %%
csv_path= '/home/jupyter-nafisha/Brain_age/CSVs/ADNI_original.csv'

# %%
import pandas as pd
ADNI_data= pd.read_csv(csv_path)
ADNI_data
# Out:
#                                        xml_file  subject_id  image_uid  \
# 0     ADNI_114_S_0374_MPRAGE_S53044_I112615.xml  114_S_0374     112615
# 1      ADNI_062_S_0793_MPRAGE_S39118_I72623.xml  062_S_0793      72623
# 2    ADNI_009_S_5037_MPRAGE_S187132_I367491.xml  009_S_5037     367491
# 3      ADNI_036_S_1001_MPRAGE_S22691_I30131.xml  036_S_1001      30131
# 4      ADNI_067_S_0828_MPRAGE_S22328_I29294.xml  067_S_0828      29294
# ..                                          ...         ...        ...
# 467   ADNI_099_S_0470_MPRAGE_S50409_I106267.xml  099_S_0470     106267
# 468  ADNI_082_S_5184_MPRAGE_S190368_I373616.xml  082_S_5184     373616
# 469   ADNI_133_S_1055_MPRAGE_S60887_I131066.xml  133_S_1055     131066
# 470    ADNI_013_S_1205_MPRAGE_S44929_I88616.xml  013_S_1205      88616
# 471  ADNI_137_S_4258_MPRAGE_S170869_I340146.xml  137_S_4258     340146
#
#                                   matched_image_folder      age sex
# 0    /home/omen/Documents/Megha/ADNI_DICOM_DATA/ADN...  78.2356   F
# 1    /home/omen/Documents/Megha/ADNI_DICOM_DATA/ADN...  70.0795   M
# 2    /home/omen/Documents/Megha/ADNI_DICOM_DATA/ADN...  67.7534   M
# 3    /home/omen/Documents/Megha/ADNI_DICOM_DATA/ADN...  69.4301   M
# 4    /home/omen/Documents/Megha/ADNI_DICOM_DATA/ADN...  77.6630   F
# ..                                                 ...      ...  ..
# 467  /home/omen/Documents/Megha/ADNI_DICOM_DATA/ADN...  88.7836   F
# 468  /home/omen/Documents/Megha/ADNI_DICOM_DATA/ADN...  72.5973   F
# 469  /home/omen/Documents/Megha/ADNI_DICOM_DATA/ADN...  86.7726   M
# 470  /home/omen/Documents/Megha/ADNI_DICOM_DATA/ADN...  84.1507   M
# 471  /home/omen/Documents/Megha/ADNI_DICOM_DATA/ADN...  76.9699   M
#
# [472 rows x 6 columns]

# %%
ADNI_data["file_path"] = (
    ADNI_data["subject_id"].astype(str)
    + "_"
    + ADNI_data["image_uid"].astype(str)
    + ".nii.gz"
)

# %%
ADNI_filtered= ADNI_data.iloc[0:50]

# %%
ADNI_filtered.to_csv('/home/jupyter-nafisha/Brain_age/CSVs/ADNI_filtered.csv', index=False)

# %%
# ADNI_filtered

# %% [markdown]
# #### xml

# %%
import pandas as pd
df= pd.read_csv('/home/jupyter-nafisha/Brain_age/CSVs/ADNI_filtered.csv')

# %%
filtered= df[['file_path', 'age', 'sex']]
filtered
# Out:
#                    file_path      age sex
# 0   114_S_0374_112615.nii.gz  78.2356   F
# 1    062_S_0793_72623.nii.gz  70.0795   M
# 2   009_S_5037_367491.nii.gz  67.7534   M
# 3    036_S_1001_30131.nii.gz  69.4301   M
# 4    067_S_0828_29294.nii.gz  77.6630   F
# 5     011_S_0010_8460.nii.gz  73.9726   F
# 6   128_S_4774_311833.nii.gz  85.9014   M
# 7    141_S_0696_76789.nii.gz  75.3260   F
# 8    013_S_1205_63933.nii.gz  83.6466   M
# 9    020_S_0213_30440.nii.gz  63.7562   M
# 10   023_S_0916_25388.nii.gz  79.8055   M
# 11   067_S_1253_73477.nii.gz  63.2712   F
# 12  099_S_1144_134477.nii.gz  79.6521   M
# 13   141_S_0790_99601.nii.gz  84.6548   F
# 14  036_S_5063_415471.nii.gz  72.6274   F
# 15   067_S_0812_49572.nii.gz  72.2658   F
# 16  073_S_4853_341846.nii.gz  71.1945   F
# 17   114_S_0374_25802.nii.gz  76.4932   F
# 18  011_S_4949_350951.nii.gz  78.3534   F
# 19  082_S_5029_378551.nii.gz  80.2630   M
# 20  082_S_5029_346808.nii.gz  79.6466   M
# 21   011_S_0053_30933.nii.gz  81.2219   M
# 22   023_S_0093_88822.nii.gz  79.4301   F
# 23   013_S_0996_35294.nii.gz  91.1479   F
# 24   062_S_0535_33235.nii.gz  77.4219   M
# 25  137_S_4258_260531.nii.gz  75.9562   M
# 26   023_S_0139_10238.nii.gz  65.9397   F
# 27    067_S_0020_7783.nii.gz  72.4384   F
# 28  114_S_4379_302292.nii.gz  88.3562   F
# 29  114_S_4379_277487.nii.gz  87.9507   F
# 30   023_S_0916_76307.nii.gz  80.8027   M
# 31   036_S_0759_71006.nii.gz  82.8712   F
# 32   082_S_1079_84075.nii.gz  79.1534   M
# 33  067_S_4728_374773.nii.gz  82.9671   M
# 34  137_S_4258_405621.nii.gz  77.9781   M
# 35   067_S_0076_44504.nii.gz  79.6795   M
# 36  135_S_5275_384344.nii.gz  78.0411   F
# 37   051_S_1296_91545.nii.gz  78.0466   M
# 38  011_S_4949_394597.nii.gz  79.2000   F
# 39  116_S_4732_307561.nii.gz  77.3425   M
# 40   057_S_1373_46230.nii.gz  75.4849   M
# 41  067_S_0076_122833.nii.gz  81.2959   M
# 42  153_S_4172_264010.nii.gz  76.1370   M
# 43   057_S_0474_55095.nii.gz  78.4795   F
# 44   057_S_1373_78131.nii.gz  76.0603   M
# 45   033_S_0724_20406.nii.gz  78.7068   M
# 46   036_S_0760_23387.nii.gz  69.4658   F
# 47   011_S_0183_11673.nii.gz  72.4986   F
# 48   036_S_0759_23138.nii.gz  81.8493   F
# 49  116_S_4625_341366.nii.gz  64.4219   M

# %%
filtered['sex'] = filtered['sex'].map({'M': 1, 'F': 2})
# Out:
# /tmp/ipykernel_525365/476915371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['sex'] = filtered['sex'].map({'M': 1, 'F': 2})

# %%
filtered
# Out:
#                    file_path      age  sex
# 0   114_S_0374_112615.nii.gz  78.2356    2
# 1    062_S_0793_72623.nii.gz  70.0795    1
# 2   009_S_5037_367491.nii.gz  67.7534    1
# 3    036_S_1001_30131.nii.gz  69.4301    1
# 4    067_S_0828_29294.nii.gz  77.6630    2
# 5     011_S_0010_8460.nii.gz  73.9726    2
# 6   128_S_4774_311833.nii.gz  85.9014    1
# 7    141_S_0696_76789.nii.gz  75.3260    2
# 8    013_S_1205_63933.nii.gz  83.6466    1
# 9    020_S_0213_30440.nii.gz  63.7562    1
# 10   023_S_0916_25388.nii.gz  79.8055    1
# 11   067_S_1253_73477.nii.gz  63.2712    2
# 12  099_S_1144_134477.nii.gz  79.6521    1
# 13   141_S_0790_99601.nii.gz  84.6548    2
# 14  036_S_5063_415471.nii.gz  72.6274    2
# 15   067_S_0812_49572.nii.gz  72.2658    2
# 16  073_S_4853_341846.nii.gz  71.1945    2
# 17   114_S_0374_25802.nii.gz  76.4932    2
# 18  011_S_4949_350951.nii.gz  78.3534    2
# 19  082_S_5029_378551.nii.gz  80.2630    1
# 20  082_S_5029_346808.nii.gz  79.6466    1
# 21   011_S_0053_30933.nii.gz  81.2219    1
# 22   023_S_0093_88822.nii.gz  79.4301    2
# 23   013_S_0996_35294.nii.gz  91.1479    2
# 24   062_S_0535_33235.nii.gz  77.4219    1
# 25  137_S_4258_260531.nii.gz  75.9562    1
# 26   023_S_0139_10238.nii.gz  65.9397    2
# 27    067_S_0020_7783.nii.gz  72.4384    2
# 28  114_S_4379_302292.nii.gz  88.3562    2
# 29  114_S_4379_277487.nii.gz  87.9507    2
# 30   023_S_0916_76307.nii.gz  80.8027    1
# 31   036_S_0759_71006.nii.gz  82.8712    2
# 32   082_S_1079_84075.nii.gz  79.1534    1
# 33  067_S_4728_374773.nii.gz  82.9671    1
# 34  137_S_4258_405621.nii.gz  77.9781    1
# 35   067_S_0076_44504.nii.gz  79.6795    1
# 36  135_S_5275_384344.nii.gz  78.0411    2
# 37   051_S_1296_91545.nii.gz  78.0466    1
# 38  011_S_4949_394597.nii.gz  79.2000    2
# 39  116_S_4732_307561.nii.gz  77.3425    1
# 40   057_S_1373_46230.nii.gz  75.4849    1
# 41  067_S_0076_122833.nii.gz  81.2959    1
# 42  153_S_4172_264010.nii.gz  76.1370    1
# 43   057_S_0474_55095.nii.gz  78.4795    2
# 44   057_S_1373_78131.nii.gz  76.0603    1
# 45   033_S_0724_20406.nii.gz  78.7068    1
# 46   036_S_0760_23387.nii.gz  69.4658    2
# 47   011_S_0183_11673.nii.gz  72.4986    2
# 48   036_S_0759_23138.nii.gz  81.8493    2
# 49  116_S_4625_341366.nii.gz  64.4219    1

# %%
filtered['file_path']= filtered['file_path'].str.replace('.nii.gz','_Warped.nii.gz')
# Out:
# /tmp/ipykernel_525365/2653560715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['file_path']= filtered['file_path'].str.replace('.nii.gz','_Warped.nii.gz')

# %%
filtered.to_excel('/home/jupyter-nafisha/Brain_age/CSVs/ADNI_filtered.xlsx', index= False)

# %% [markdown]
# ### inference

# %%
import os
import subprocess
import torch
from torch.utils.data import DataLoader
from monai import transforms
from monai.data import Dataset
from monai.networks.nets.densenet import DenseNet201

# %%
template_path = '/home/jupyter-nafisha/Brain_age/templates/MNI152_T1_1mm_Brain.nii.gz'
model_path = "/home/jupyter-nafisha/Brain_age/synthstrip.pt"

# %%
ants_bin = "/home/jupyter-nafisha/Brain_age/ants_2_6_3/ants-2.6.3/bin"
env = os.environ.copy()
env["PATH"] = ants_bin + ":" + env["PATH"]

def preprocessing(input_path, model_path, template_path):
    strip_out = os.path.join('/home/jupyter-nafisha/Brain_age/adni_preprocessed/stripped', input_path)
    input_path= os.path.join('/home/jupyter-nafisha/Brain_age/Alzheimer_ADNI_data', input_path)
    
    cmd = [
        "/home/jupyter-nafisha/.local/bin/nipreps-synthstrip",
        "-i", input_path,
        "-o", strip_out,
        "--model", model_path
    ]
    # if not os.path.exists(strip_out)
    result = subprocess.run(cmd, capture_output=True, text=True)
    # result = subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # print(cmd)

    base_name = os.path.basename(input_path).replace(".nii.gz", "").replace(".nii", "")
    output_path = os.path.join('/home/jupyter-nafisha/Brain_age/adni_preprocessed/registered', base_name +'_')
    reg_cmd = [
        f"{ants_bin}/antsRegistrationSyNQuick.sh",
        "-d", "3",
        "-f", template_path,
        "-m", strip_out,
        "-o", output_path,
        "-n", str(os.cpu_count()),   
        "-t", "a"
    ]
    subprocess.run(reg_cmd, env=env, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    # print(reg_cmd)
    # print(os.path.exists(input_path))
    # print(os.path.exists(strip_out))
    # print(os.path.exists(output_path))
    # print(strip_out, output_path)
    
    return output_path + "Warped.nii.gz"

# %%
def get_inputs(inputs_path: str) -> list:
    
    def get_inputs_from_dir(inputs_path: str) -> list:
        is_nii = lambda f: f.endswith('.nii') or f.endswith('.nii.gz')
        files = os.listdir(inputs_path)
        input_paths = [ os.path.join(inputs_path, f) for f in files if is_nii(f) ]
        return input_paths

    def get_inputs_from_csv(inputs_path: str) -> list:
        with open(inputs_path, 'r') as f:
            return [ p.strip() for p in f.readlines() ]
        
    return get_inputs_from_dir(inputs_path) if os.path.isdir(inputs_path) \
        else get_inputs_from_csv(inputs_path)

transforms_fn = transforms.Compose([
    transforms.CopyItemsD(keys={'scan_path'}, names=['image']),
    transforms.LoadImageD(keys='image'),
    transforms.EnsureChannelFirstD(keys='image', channel_dim='no_channel'),
    transforms.SpacingD(keys='image', pixdim=1.4),
    transforms.ResizeWithPadOrCropD(keys='image', spatial_size=(130, 130, 130), mode='minimum'),
    transforms.ScaleIntensityD(keys='image', minv=0, maxv=1),
    transforms.Lambda(lambda d: d['image']),
])

# %%
densenet_path = '/home/jupyter-nafisha/Brain_age/synthba-g.pth'
DEVICE = 'cpu'
batch_size = 1

model = DenseNet201(3, 1, 1, dropout_prob=0)
model.load_state_dict(torch.load(densenet_path, map_location=DEVICE))
model = model.to(DEVICE).eval()

# %%
import pandas as pd
data= pd.read_csv('/home/jupyter-nafisha/Brain_age/CSVs/ADNI_filtered.csv')
input_paths= list(data['file_path'])

# %%
# input_paths

# %%
brain_age_list = []
full_list = []

for path in input_paths:
    out_path= preprocessing(path, model_path, template_path)

    dataset = Dataset(data= [{ 'scan_path': out_path }], transform=transforms_fn)  
    loader = DataLoader(dataset=dataset, batch_size=1)

    for i, images in enumerate(loader):
        print(f'processing batch n.{i}')
        with torch.no_grad():
            brain_ages = model(images.to(DEVICE))
            brain_age_list += list(brain_ages.view(-1).cpu().numpy() * 100)
            # full_list.append([path, brain_ages.view(-1).cpu().numpy() * 100])
        print(path, brain_ages.view(-1).cpu().numpy() * 100)
# Out:
# processing batch n.0
# 114_S_0374_112615.nii.gz [89.99128]
# processing batch n.0
# 062_S_0793_72623.nii.gz [80.09013]
# processing batch n.0
# 009_S_5037_367491.nii.gz [82.97655]
# processing batch n.0
# 036_S_1001_30131.nii.gz [71.54692]
# processing batch n.0
# 067_S_0828_29294.nii.gz [76.36732]
# processing batch n.0
# 011_S_0010_8460.nii.gz [76.28421]
# processing batch n.0
# 128_S_4774_311833.nii.gz [87.483505]
# processing batch n.0
# 141_S_0696_76789.nii.gz [73.02826]
# processing batch n.0
# 013_S_1205_63933.nii.gz [74.93393]
# processing batch n.0
# 020_S_0213_30440.nii.gz [78.25242]
# processing batch n.0
# 023_S_0916_25388.nii.gz [79.0029]
# processing batch n.0
# 067_S_1253_73477.nii.gz [65.3431]
# processing batch n.0
# 099_S_1144_134477.nii.gz [88.55624]
# processing batch n.0
# 141_S_0790_99601.nii.gz [83.26864]
# processing batch n.0
# 036_S_5063_415471.nii.gz [87.314354]
# processing batch n.0
# 067_S_0812_49572.nii.gz [80.59377]
# processing batch n.0
# 073_S_4853_341846.nii.gz [86.89461]
# processing batch n.0
# 114_S_0374_25802.nii.gz [89.44332]
# processing batch n.0
# 011_S_4949_350951.nii.gz [70.366615]
# processing batch n.0
# 082_S_5029_378551.nii.gz [92.231766]
# processing batch n.0
# 082_S_5029_346808.nii.gz [91.15476]
# processing batch n.0
# 011_S_0053_30933.nii.gz [81.80809]
# processing batch n.0
# 023_S_0093_88822.nii.gz [88.04691]
# processing batch n.0
# 013_S_0996_35294.nii.gz [81.39668]
# processing batch n.0
# 062_S_0535_33235.nii.gz [83.72436]
# processing batch n.0
# 137_S_4258_260531.nii.gz [76.070724]
# processing batch n.0
# 023_S_0139_10238.nii.gz [74.96647]
# processing batch n.0
# 067_S_0020_7783.nii.gz [79.397545]
# processing batch n.0
# 114_S_4379_302292.nii.gz [81.18881]
# processing batch n.0
# 114_S_4379_277487.nii.gz [80.669426]
# processing batch n.0
# 023_S_0916_76307.nii.gz [82.439445]
# processing batch n.0
# 036_S_0759_71006.nii.gz [88.14404]
# processing batch n.0
# 082_S_1079_84075.nii.gz [72.92823]
# processing batch n.0
# 067_S_4728_374773.nii.gz [92.71547]
# processing batch n.0
# 137_S_4258_405621.nii.gz [78.77764]
# processing batch n.0
# 067_S_0076_44504.nii.gz [86.4093]
# processing batch n.0
# 135_S_5275_384344.nii.gz [74.65158]
# processing batch n.0
# 051_S_1296_91545.nii.gz [76.98867]
# processing batch n.0
# 011_S_4949_394597.nii.gz [67.95296]
# processing batch n.0
# 116_S_4732_307561.nii.gz [75.09525]
# processing batch n.0
# 057_S_1373_46230.nii.gz [81.67241]
# processing batch n.0
# 067_S_0076_122833.nii.gz [86.97986]
# processing batch n.0
# 153_S_4172_264010.nii.gz [70.948044]
# processing batch n.0
# 057_S_0474_55095.nii.gz [81.657585]
# processing batch n.0
# 057_S_1373_78131.nii.gz [81.352684]
# processing batch n.0
# 033_S_0724_20406.nii.gz [82.72065]
# processing batch n.0
# 036_S_0760_23387.nii.gz [82.54366]
# processing batch n.0
# 011_S_0183_11673.nii.gz [82.01665]
# processing batch n.0
# 036_S_0759_23138.nii.gz [87.550766]
# processing batch n.0
# 116_S_4625_341366.nii.gz [72.884865]

# %%
csv_path = '/home/jupyter-nafisha/Brain_age/CSVs/adni_synthBA.csv'
with open(csv_path, 'w') as csv:
    csv.write("input_id,brainage\n")
    for scan_path, brain_age in zip(input_paths, brain_age_list):
        csv.write(f"{scan_path},{brain_age}\n")

# %% [markdown]
# ### MAE

# %%
import pandas as pd

pred_path= '/home/jupyter-nafisha/Brain_age/CSVs/adni_synthBA.csv'
act_path= '/home/jupyter-nafisha/Brain_age/CSVs/ADNI_filtered.csv'
# final= merged['input_id', ]

pred= pd.read_csv(pred_path)
pred= pred.rename(columns={'brainage':'predicted_brainage'})
pred.to_csv(pred_path, index= False)

act= pd.read_csv(act_path)

merged= pred.merge(
    act,
    left_on= 'input_id',
    right_on= 'file_path',
    how= 'inner'
)

final= merged[['input_id', 'age' , 'predicted_brainage']]

# %%
# final

# %%
final.to_csv(pred_path, index= False)

# %%
import numpy as np

mae = np.mean(np.abs(final['age'] - final['predicted_brainage']))
print("MAE =", mae)
# Out:
# MAE = 6.731220975585938

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
plt.scatter(final['age'], final['predicted_brainage'], alpha=0.6)

# Add diagonal y=x line
x = np.linspace(final['age'].min(), final['age'].max(), 100)
plt.plot(x, x, linestyle='--')

plt.xlabel('Actual Age')
plt.ylabel('Predicted Brain Age')
plt.title('Actual Age vs Predicted Brain Age')
plt.grid(True)
plt.show()
